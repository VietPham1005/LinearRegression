# %% [markdown]
# <a href="https://colab.research.google.com/github/VietPham1005/Machine-Learning/blob/main/GooglePlayStore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UPLOAD DATA

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e656df3c-88f7-4aca-a3cc-2958403290ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e656df3c-88f7-4aca-a3cc-2958403290ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # IMPORT THƯ VIỆN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
plt.rcParams.update({'figure.figsize':(7,3), 'figure.dpi':120})

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # KIỂM TRA UNIQUE CÁC DỮ LIỆU CÓ TÍNH PHÂN NHÓM: CATEGORY, TYPE, CONTENT RATING, GENRES

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
df['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %% [markdown]
# # KIỂM TRA DATA TYPE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # **CLEAN DATA - CHANGE TYPE**

# %%
# 1) Clean 'Reviews' và đổi 'object' => 'float'
reviews = [i for i in df['Reviews']]

def clean_reviews(reviews_list):
    """ĐỔI M THÀNH TRIỆU """
    cleaned_data = []
    for review in reviews_list:
        if 'M' in review:
            review = review.replace('M', '')
            review = float(review) * 1000000  # 1M = 1,000,000
        cleaned_data.append(review)
    return cleaned_data

df['Reviews'] = clean_reviews(reviews)
df['Reviews'] = df['Reviews'].astype(float)

# %%
# 2) Clean 'Size' và đổi 'object' => 'float'

# Phát hiện giá trị có chứa '1,000+' trong một bản ghi, loại bỏ nó khỏi data_frame vì không chắc chắn nó có phải là 'M' hay 'K'

index = df[df['Size'] == '1,000+'].index
df.drop(axis=0, inplace=True, index=index)

sizes = [i for i in df['Size']]

def clean_sizes(sizes_list):
    cleaned_data = []
    for size in sizes_list:
        if 'M' in size:
            size = size.replace('M', '')
            size = float(size)
        elif 'k' in size:
            size = size.replace('k', '')
            size = float(size)
            size = size/1024  # 1 Megabyte = 1024 kilobytes
        # Thay thế cho giá trị 'Varies with device' với giá trị 0.
        elif 'Varies with device' in size:
            size = float(0)
        cleaned_data.append(size)
    return cleaned_data

df['Size'] = clean_sizes(sizes)
df['Size'] = df['Size'].astype(float)

# %%
# 3) Clean 'Installs' và đổi 'object' => 'float'
installs = [i for i in df['Installs']]

def clean_installs(installs_list):
    cleaned_data = []
    for install in installs_list:
        if ',' in install:
            install = install.replace(',', '')
        if '+' in install:
            install = install.replace('+', '')
        install = int(install)
        cleaned_data.append(install)
    return cleaned_data

df['Installs'] = clean_installs(installs)
df['Installs'] = df['Installs'].astype(float)

# %%
# 4) Clean the 'Price' và đổi 'object' => 'float'
prices = [i for i in df['Price']]

def clean_prices(prices_list):
    cleaned_data = []
    for price in prices_list:
        if '$' in price:
            price = price.replace('$', '')
        cleaned_data.append(price)
    return cleaned_data

df['Price'] = clean_prices(prices)
df['Price'] = df['Price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  float64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 1.2+ MB

# %%
df.sample(10)
# Out:
#                                                      App             Category  \
# 8162                                             MYTO CZ  MAPS_AND_NAVIGATION
# 788                          Udacity - Lifelong Learning            EDUCATION
# 1069                                         MyMo by GSB              FINANCE
# 801    Rosetta Stone: Learn to Speak & Read New Langu...            EDUCATION
# 1676                                       Magic Tiles 3                 GAME
# 143                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 5972                                          BC's Pizza            LIFESTYLE
# 10436                            Forgotten Hill: Surgery                 GAME
# 7021                        Best Hairstyles step by step               BEAUTY
# 5841                           Ay Yıldız Duvar Kağıtları      PERSONALIZATION
#
#        Rating   Reviews  Size     Installs  Type  Price Content Rating  \
# ...

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
# thay thế các dòng có giá trị null bằng giá trị trung vị
def replace_with_median(series):
    return series.fillna(series.median())

df['Rating'] = df['Rating'].transform(replace_with_median)
df['Rating'] = df['Rating'].astype(float)

# %%
# remove 'Type' có giá trị null
index = df[df['Type'].isna()].index
df.drop(axis=0, inplace=True, index=index)

# %%
# check on null values
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# # GROUPBY DỮ LIỆU THEO APP

# %%
# Nhóm dữ liệu bắt đầu bằng cột "App" và "Reviews"
df = df.groupby(['App', 'Reviews', 'Category', 'Rating', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres',
                           'Last Updated', 'Current Ver', 'Android Ver'], as_index=False)
# Gán lại giá trị của cột Installs bằng giá trị trung bình của cột này. Các giá trị của cột Installs sẽ không còn quá lớn hoặc quá bé
df = df['Installs'].mean()
# Sắp xếp DataFrame theo thứ tự giảm dần của cột "Reviews".
df.sort_values(by='Reviews', ascending=False, inplace=True)
# Loại bỏ các hàng trùng lặp dựa trên cột "App".
df.drop_duplicates(subset=['App'], inplace=True)
df
# Out:
#                                              App     Reviews       Category  \
# 4534                                    Facebook  78158306.0         SOCIAL
# 9661                          WhatsApp Messenger  69119316.0  COMMUNICATION
# 5731                                   Instagram  66577446.0         SOCIAL
# 6546    Messenger – Text and Video Chat for Free  56646578.0  COMMUNICATION
# 2701                              Clash of Clans  44893888.0           GAME
# ...                                          ...         ...            ...
# 4372                      FG Autumn Photo Puzzle         0.0         FAMILY
# 4369  FE Other Disciplines Engineering Exam Prep         0.0         FAMILY
# 9033                             Thyroid Nodules         0.0        MEDICAL
# 185                            ACCEPT CE MARKING         0.0   PRODUCTIVITY
# 5862           K-App Mitarbeiter Galeria Kaufhof         0.0   PRODUCTIVITY
#
# ...

# %%
df.describe()
# Out:
#             Reviews       Rating         Size        Price      Installs
# count  9.648000e+03  9648.000000  9648.000000  9648.000000  9.648000e+03
# mean   2.170487e+05     4.192485    17.820208     1.098122  7.806898e+06
# std    1.832460e+06     0.496210    21.503151    16.861193  5.379975e+07
# min    0.000000e+00     1.000000     0.000000     0.000000  0.000000e+00
# 25%    2.500000e+01     4.000000     2.900000     0.000000  1.000000e+03
# 50%    9.745000e+02     4.300000     9.200000     0.000000  1.000000e+05
# 75%    2.949750e+04     4.500000    25.000000     0.000000  1.000000e+06
# max    7.815831e+07     5.000000   100.000000   400.000000  1.000000e+09

# %% [markdown]
# # VISUAL DATA

# %% [markdown]
# ## SỐ LƯỢNG APP TRÊN MỖI CATEGORY

# %%
# lấy số lượng ứng dụng cho mỗi danh mục
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='Category', data=df)
plt.title('Number of Apps Per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# *Ta thấy App có Category Family được viết nhiều nhất, tiếp theo là Game và Tools*

# %% [markdown]
# ## SỐ LƯỢNG CÀI ĐẶT TRÊN MỖI CATEGORY

# %%
categories = df.groupby('Category')
category_installs_sum_df = categories[['Installs']].sum()
category_installs_sum_df = category_installs_sum_df.reset_index()  # to convert groupby object into dataframe

plt.figure(figsize=(10, 5))
sns.barplot(x='Category', y='Installs', data=category_installs_sum_df)
plt.xticks(rotation=90)
plt.ylabel('Installs (e+10)')
plt.title('Number of Installs For Each Category')
plt.show()

# %% [markdown]
# *Mặc dù là Category có số lượng App chỉ đứng thứ 2. Nhưng Game được cài đặt nhiều nhất. Tiếp theo là Nhu cầu Kết nối (Mạng xã hội) - Tools và Family lần lượt thứ 3 và 4*

# %% [markdown]
# ## SỰ PHÂN BỐ ĐÁNH GIÁ RATING

# %%
# show the distribution of rating
plt.figure(figsize=(10, 5))
sns.countplot(x='Rating', data=df)
plt.title('Rating Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# *Mức Rating nhiều ở khu vực 4.0 đến 4.7 - Nhiều nhất là 4.3*

# %% [markdown]
# ## RATING PER REVIEWS, SIZE, INSTALLS, PRICE

# %%
# Vẽ các đồ thị cho số lượng đánh giá (reviews), kích thước ứng dụng (size), số lần tải (installs) và giá của ứng dụng (price) theo từng mức đánh giá (rating).
rating_df = df.groupby('Rating').sum().reset_index()

fig, axes = plt.subplots(1, 4, figsize=(14, 4))

axes[0].plot(rating_df['Rating'], rating_df['Reviews'], 'r')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')

axes[1].plot(rating_df['Rating'], rating_df['Size'], 'g')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Size')
axes[1].set_title('Size Per Rating')

axes[2].plot(rating_df['Rating'], rating_df['Installs'], 'g')
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Installs (e+10)')
axes[2].set_title('Installs Per Rating')

axes[3].plot(rating_df['Rating'], rating_df['Price'], 'k')
axes[3].set_xlabel('Rating')
axes[3].set_ylabel('Price')
axes[3].set_title('Price Per Rating')

plt.tight_layout(pad=2)
plt.show()
# Out:
# <ipython-input-31-291cd213af38>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rating_df = df.groupby('Rating').sum().reset_index()

# %% [markdown]
# *Từ các biểu đồ trên, chúng ta có thể suy ra rằng hầu hết các ứng dụng có mức đánh giá cao từ 4.0 - 4.7 thường có số lượng đánh giá, kích thước và số lần tải cao. Tuy nhiên, về mặt giá, nó không phản ánh một mối quan hệ trực tiếp với mức đánh giá, bởi vì chúng ta có thể thấy sự dao động về giá cả ngay cả ở mức đánh giá cao.*

# %% [markdown]
# ## SỐ APPS FREE / TRẢ PHÍ

# %%
# application type distribution
plt.figure(figsize=(10, 5))
sns.countplot(x='Type', data=df)
plt.title('Type Distribution')
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# *Từ biểu đồ, chúng ta có thể suy ra rằng đa số các ứng dụng trên Google Play Store là ứng dụng miễn phí (Free apps).*

# %% [markdown]
# # HIỂN THỊ PHÂN PHỐI APP THEO RATING, SIZE VÀ TYPE

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Size',y='Rating',hue='Type',s=50, data=df)
# Out:
# <Axes: xlabel='Size', ylabel='Rating'>

# %% [markdown]
# *Từ biểu đồ scatter plot này, chúng ta có thể suy ra rằng đa số các ứng dụng miễn phí có kích thước nhỏ và có mức đánh giá cao. Trong khi đó, đối với các ứng dụng trả phí, chúng ta có phân bố khá đồng đều về kích thước và mức đánh giá.*

# %% [markdown]
# CHỌN CÁCH BIẾN PHÂN LOẠI: Category, Type, Content Rating

# %% [markdown]
# # TÌM MÔ HÌNH DỰ ĐOÁN CHO RATING

# %% [markdown]
# ##CHUẨN BỊ DATA

# %%
#Chọn các cột có tính Phân Loại
feature_selected_df = df
feature_selected_df.drop(['App','Price','Last Updated','Current Ver','Android Ver'],axis=1,inplace=True)
feature_selected_df
# Out:
#          Reviews       Category  Rating  Size  Type Content Rating  \
# 4534  78158306.0         SOCIAL     4.1   0.0  Free           Teen
# 9661  69119316.0  COMMUNICATION     4.4   0.0  Free       Everyone
# 5731  66577446.0         SOCIAL     4.5   0.0  Free           Teen
# 6546  56646578.0  COMMUNICATION     4.0   0.0  Free       Everyone
# 2701  44893888.0           GAME     4.6  98.0  Free   Everyone 10+
# ...          ...            ...     ...   ...   ...            ...
# 4372         0.0         FAMILY     4.3   4.6  Free       Everyone
# 4369         0.0         FAMILY     4.3  21.0  Free       Everyone
# 9033         0.0        MEDICAL     4.3  20.0  Free       Everyone
# 185          0.0   PRODUCTIVITY     4.3  30.0  Free       Everyone
# 5862         0.0   PRODUCTIVITY     4.3  19.0  Free       Everyone
#
#              Genres      Installs
# 4534         Social  1.000000e+09
# 9661  Communication  1.000000e+09
# 5731         Social  1.000000e+09
# ...

# %%
# Using one hot encoding for categorical data
catg=pd.get_dummies(feature_selected_df['Category'],prefix='catg',drop_first=True)
typ=pd.get_dummies(feature_selected_df['Type'],prefix='typ',drop_first=True)
ctr=pd.get_dummies(feature_selected_df['Content Rating'],prefix='ctr',drop_first=True)
gen=pd.get_dummies(feature_selected_df['Genres'],prefix='gen',drop_first=True)

frames=[feature_selected_df,catg,typ,ctr,gen]
feature_selected_df=pd.concat(frames,axis=1)
feature_selected_df.drop(['Category','Type','Content Rating','Genres'],axis=1,inplace=True)

# %%
X=feature_selected_df.drop('Rating',axis=1)
y=feature_selected_df['Rating'].values
y=y.astype('int')

# %% [markdown]
# #TRAIN DATA

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

# %% [markdown]
# ## DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
# DecisionTree Classifier
dtree_c= DecisionTreeClassifier(criterion='entropy',random_state=0)
dtree_c.fit(X_train,y_train)
dtree_pred=dtree_c.predict(X_test)
dtree_cm=confusion_matrix(y_test,dtree_pred)
dtree_ac=accuracy_score(dtree_pred,y_test)

# %%
plt.figure(figsize=(10,5))
plt.title("dtree_cm")
sns.heatmap(dtree_cm,annot=True,fmt="d",cbar=False,xticklabels=[1, 2, 3, 4, 5], yticklabels=[1, 2, 3, 4, 5])
print('DecisionTree_Classifier_accuracy:',dtree_ac)
print("The F1 score is: ", f1_score(y_test, dtree_pred, average="macro"))
print("The Precision score is: ",precision_score(y_test, dtree_pred, average="macro",zero_division=1))
print("The Recall score is: ",recall_score(y_test, dtree_pred, average="macro"))
# Out:
# DecisionTree_Classifier_accuracy: 0.679447322970639
# The F1 score is:  0.28927181049438555
# The Precision score is:  0.2899873196507716
# The Recall score is:  0.28918422207446554

# %% [markdown]
# ##LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#LogisticRegression

lr_c = LogisticRegression(random_state=0, solver='saga', max_iter=8000)
lr_c.fit(X_train_scaled,y_train)
lr_pred=lr_c.predict(X_test_scaled)
lr_cm=confusion_matrix(y_test,lr_pred)
lr_ac=accuracy_score(y_test, lr_pred)

print('LogisticRegression_accuracy:',lr_ac)

import sklearn.metrics as metrics
print('MAE:', metrics.mean_absolute_error(y_test, lr_pred))
print('MSE:', metrics.mean_squared_error(y_test, lr_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, lr_pred)))
# Out:
# LogisticRegression_accuracy: 0.7668393782383419
# MAE: 0.26493955094991367
# MSE: 0.3395509499136442
# RMSE: 0.5827100049884542

# %%
plt.figure(figsize=(10,5))
plt.title("lr_cm")
sns.heatmap(lr_cm,annot=True,cmap="Blues",fmt="d",cbar=False,xticklabels=[1, 2, 3, 4, 5], yticklabels=[1, 2, 3, 4, 5])
plt.show()

# %% [markdown]
# ##RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
#RandomForest
rdf_c=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
rdf_c.fit(X_train,y_train)
rdf_pred=rdf_c.predict(X_test)
rdf_cm=confusion_matrix(y_test,rdf_pred)
rdf_ac=accuracy_score(rdf_pred,y_test)
print('The accuracy of the model is:',rdf_ac)
print("The F1 score is: ", f1_score(y_test, rdf_pred, average="macro"))
print("The Precision score is: ",precision_score(y_test, rdf_pred, average="macro",zero_division=1))
print("The Recall score is: ",recall_score(y_test, rdf_pred, average="macro"))

import sklearn.metrics as metrics
print('MAE:', metrics.mean_absolute_error(y_test, rdf_pred))
print('MSE:', metrics.mean_squared_error(y_test, rdf_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, rdf_pred)))
# Out:
# The accuracy of the model is: 0.722279792746114
# The F1 score is:  0.26397752631947824
# The Precision score is:  0.2921629047129352
# The Recall score is:  0.254051197304756
# MAE: 0.3157167530224525
# MSE: 0.4048359240069085
# RMSE: 0.6362671797341967

# %%
plt.figure(figsize=(10,5))
plt.title("rdf_cm")
sns.heatmap(rdf_cm,annot=True,cmap="Blues",fmt="d",cbar=False,xticklabels=[1, 2, 3, 4, 5], yticklabels=[1, 2, 3, 4, 5])
print('RandomForest_accuracy:',rdf_ac)
# Out:
# RandomForest_accuracy: 0.722279792746114

# %% [markdown]
# ##SVM REGRESSOR

# %%
from sklearn.svm import SVC

# %%
#SVM regressor
svc_r=SVC(kernel='rbf')
svc_r.fit(X_train,y_train)
svr_pred=svc_r.predict(X_test)
svr_cm=confusion_matrix(y_test,svr_pred)
svr_ac=accuracy_score(y_test, svr_pred)

# %%
plt.figure(figsize=(10,5))
plt.title("svm_cm")
sns.heatmap(svr_cm,annot=True,cmap="Oranges",fmt="d",cbar=False,xticklabels=[1, 2, 3, 4, 5], yticklabels=[1, 2, 3, 4, 5])
print('SVM_regressor_accuracy:',svr_ac)
# Out:
# SVM_regressor_accuracy: 0.7671848013816925

# %% [markdown]
# #SO SÁNH CÁC MÔ HÌNH

# %%
model_accuracy = pd.Series(data=[lr_ac,dtree_ac,svr_ac,rdf_ac],
        index=['Logistic_Regression','DecisionTree_Classifier','SVM_regressor_accuracy','RandomForest'])
fig= plt.figure(figsize=(8,8))
model_accuracy.sort_values().plot.barh()
plt.title('Model Accracy')
# Out:
# Text(0.5, 1.0, 'Model Accracy')
